# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Research\EndpointXAI\data\mordor_labeled.csv")
print(f"Loaded {len(df)} events")
print(df['attack_label'].value_counts())
# Out:
# Loaded 630238 events
# attack_label
# defense_evasion     242239
# lateral_movement    196869
# persistence         191130
# Name: count, dtype: int64

# %%
# Use only columns with sufficient data
df['TargetObject'] = df['TargetObject'].fillna('unknown')

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['TargetObject_enc'] = le.fit_transform(df['TargetObject'].astype(str))

# Final features
x = df[['EventID', 'TargetObject_enc']]
y = df['attack_label']

print(f"Features shape: {X.shape}")
print(f"Labels shape: {y.shape}")
print(x.head())
# Out:
# Features shape: (630238, 2)
# Labels shape: (630238,)
#    EventID  TargetObject_enc
# 0     5058             44205
# 1     5061             44205
# 2     5058             44205
# 3     5061             44205
# 4     5058             44205

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

print(f"Train size: {X_train.shape}")
print(f"Test size: {X_test.shape}")
print(f"Label distribution in train:")
print(y_train.value_counts())
# Out:
# Train size: (504190, 5)
# Test size: (126048, 5)
# Label distribution in train:
# attack_label
# defense_evasion     193791
# lateral_movement    157495
# persistence         152904
# Name: count, dtype: int64

# %%
import numpy as np

X_train.to_csv(r"C:\Research\EndpointXAI\data\X_train.csv", index=False)
X_test.to_csv(r"C:\Research\EndpointXAI\data\X_test.csv", index=False)
y_train.to_csv(r"C:\Research\EndpointXAI\data\y_train.csv", index=False)
y_test.to_csv(r"C:\Research\EndpointXAI\data\y_test.csv", index=False)

print("All splits saved!")
# Out:
# All splits saved!
